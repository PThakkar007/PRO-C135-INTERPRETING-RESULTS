# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('total_stars.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('total_stars.csv')
#       2 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'total_stars.csv'

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Star_name', 'Distance', 'Mass', 'Radius', 'Luminosity',
#        'Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1','Luminosity'],axis=1,inplace=True)

# %%
df
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 249  2MASSI J2356547-155310         74.0            0.07636704
# 250          WISE 0410+1502         20.0           0.005727528
# 251         WISE 0458+6434A         35.9  0.014318820000000001
# 252         WISE 0458+6434B         35.9            0.00954588
# 253          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# 249  0.11201167000000001
# 250  0.12023270999999998
# 251            0.4316046
# 252  0.39049939999999994
# 253           0.08837618
#
# [254 rows x 4 columns]

# %%
final_data = df.dropna()
final_data
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 249  2MASSI J2356547-155310         74.0            0.07636704
# 250          WISE 0410+1502         20.0           0.005727528
# 251         WISE 0458+6434A         35.9  0.014318820000000001
# 252         WISE 0458+6434B         35.9            0.00954588
# 253          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# 249  0.11201167000000001
# 250  0.12023270999999998
# 251            0.4316046
# 252  0.39049939999999994
# 253           0.08837618
#
# [253 rows x 4 columns]

# %%
final_data.reset_index(drop=True,inplace = True)
final_data
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 248  2MASSI J2356547-155310         74.0            0.07636704
# 249          WISE 0410+1502         20.0           0.005727528
# 250         WISE 0458+6434A         35.9  0.014318820000000001
# 251         WISE 0458+6434B         35.9            0.00954588
# 252          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# 248  0.11201167000000001
# 249  0.12023270999999998
# 250            0.4316046
# 251  0.39049939999999994
# 252           0.08837618
#
# [253 rows x 4 columns]

# %%
final_data.to_csv('final_data.csv')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 4 columns):
# Star_name    253 non-null object
# Distance     253 non-null object
# Mass         253 non-null object
# Radius       253 non-null object
# dtypes: object(4)
# memory usage: 8.0+ KB

# %%
final_data.describe()
# Out:
#                           Star_name Distance                  Mass  \
# count                           253      253                   253
# unique                          253      199                   156
# top     2MASSI J1217110-031113 [de]     51.0  0.040092696000000004
# freq                              1        4                     7
#
#                      Radius
# count                   253
# unique                  144
# top     0.09659721999999998
# freq                     20

# %%
final_data.head(5)
# Out:
#         Star_name     Distance Mass Radius
# 0             Sun  0.000015813    1      1
# 1          Sirius       0008.6  2.1  1.71´
# 2         Canopus         0310   15     71
# 3  Alpha Centauri       0004.4  1.1    1.2
# 4        Arcturus         0037  1.1     26

# %%
final_data.dtypes
# Out:
# Star_name    object
# Distance     object
# Mass         object
# Radius       object
# dtype: object
